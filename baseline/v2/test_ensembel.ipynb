# %%
import timm
from timm.data import resolve_data_config
from timm.data.transforms_factory import create_transform

# %%
model_names = timm.list_models(pretrained=True)
print(model_names)
# Out:
# ['adv_inception_v3', 'bat_resnext26ts', 'beit_base_patch16_224', 'beit_base_patch16_224_in22k', 'beit_base_patch16_384', 'beit_large_patch16_224', 'beit_large_patch16_224_in22k', 'beit_large_patch16_384', 'beit_large_patch16_512', 'beitv2_base_patch16_224', 'beitv2_base_patch16_224_in22k', 'beitv2_large_patch16_224', 'beitv2_large_patch16_224_in22k', 'botnet26t_256', 'cait_m36_384', 'cait_m48_448', 'cait_s24_224', 'cait_s24_384', 'cait_s36_384', 'cait_xs24_384', 'cait_xxs24_224', 'cait_xxs24_384', 'cait_xxs36_224', 'cait_xxs36_384', 'coat_lite_mini', 'coat_lite_small', 'coat_lite_tiny', 'coat_mini', 'coat_tiny', 'coatnet_0_rw_224', 'coatnet_1_rw_224', 'coatnet_bn_0_rw_224', 'coatnet_nano_rw_224', 'coatnet_rmlp_1_rw_224', 'coatnet_rmlp_nano_rw_224', 'convit_base', 'convit_small', 'convit_tiny', 'convmixer_768_32', 'convmixer_1024_20_ks9_p14', 'convmixer_1536_20', 'convnext_atto', 'convnext_atto_ols', 'convnext_base', 'convnext_base_384_in22ft1k', 'convnext_base_in22ft1k', 'convnext_base_in22k', 'convnext_femto', 'convnext_femto_ols', 'convnext_large', 'convnext_large_384_in22ft1k', 'convnext_large_in22ft1k', 'convnext_large_in22k', 'convnext_nano', 'convnext_nano_ols', 'convnext_pico', 'convnext_pico_ols', 'convnext_small', 'convnext_small_384_in22ft1k', 'convnext_small_in22ft1k', 'convnext_small_in22k', 'convnext_tiny', 'convnext_tiny_384_in22ft1k', 'convnext_tiny_hnf', 'convnext_tiny_in22ft1k', 'convnext_tiny_in22k', 'convnext_xlarge_384_in22ft1k', 'convnext_xlarge_in22ft1k', 'convnext_xlarge_in22k', 'crossvit_9_240', 'crossvit_9_dagger_240', 'crossvit_15_240', 'crossvit_15_dagger_240', 'crossvit_15_dagger_408', 'crossvit_18_240', 'crossvit_18_dagger_240', 'crossvit_18_dagger_408', 'crossvit_base_240', 'crossvit_small_240', 'crossvit_tiny_240', 'cs3darknet_focus_l', 'cs3darknet_focus_m', 'cs3darknet_l', 'cs3darknet_m', 'cs3darknet_x', 'cs3edgenet_x', 'cs3se_edgenet_x', 'cs3sedarknet_l', 'cs3sedarknet_x', 'cspdarknet53', 'cspresnet50', 'cspresnext50', 'darknet53', 'darknetaa53', 'deit3_base_patch16_224', 'deit3_base_patch16_224_in21ft1k', 'deit3_base_patch16_384', 'deit3_base_patch16_384_in21ft1k', 'deit3_huge_patch14_224', 'deit3_huge_patch14_224_in21ft1k', 'deit3_large_patch16_224', 'deit3_large_patch16_224_in21ft1k', 'deit3_large_patch16_384', 'deit3_large_patch16_384_in21ft1k', 'deit3_medium_patch16_224', 'deit3_medium_patch16_224_in21ft1k', 'deit3_small_patch16_224', 'deit3_small_patch16_224_in21ft1k', 'deit3_small_patch16_384', 'deit3_small_patch16_384_in21ft1k', 'deit_base_distilled_patch16_224', 'deit_base_distilled_patch16_384', 'deit_base_patch16_224', 'deit_base_patch16_384', 'deit_small_distilled_patch16_224', 'deit_small_patch16_224', 'deit_tiny_distilled_patch16_224', 'deit_tiny_patch16_224', 'densenet121', 'densenet161', 'densenet169', 'densenet201', 'densenetblur121d', 'dla34', 'dla46_c', 'dla46x_c', 'dla60', 'dla60_res2net', 'dla60_res2next', 'dla60x', 'dla60x_c', 'dla102', 'dla102x', 'dla102x2', 'dla169', 'dm_nfnet_f0', 'dm_nfnet_f1', 'dm_nfnet_f2', 'dm_nfnet_f3', 'dm_nfnet_f4', 'dm_nfnet_f5', 'dm_nfnet_f6', 'dpn68', 'dpn68b', 'dpn92', 'dpn98', 'dpn107', 'dpn131', 'eca_botnext26ts_256', 'eca_halonext26ts', 'eca_nfnet_l0', 'eca_nfnet_l1', 'eca_nfnet_l2', 'eca_resnet33ts', 'eca_resnext26ts', 'ecaresnet26t', 'ecaresnet50d', 'ecaresnet50d_pruned', 'ecaresnet50t', 'ecaresnet101d', 'ecaresnet101d_pruned', 'ecaresnet269d', 'ecaresnetlight', 'edgenext_base', 'edgenext_small', 'edgenext_small_rw', 'edgenext_x_small', 'edgenext_xx_small', 'efficientformer_l1', 'efficientformer_l3', 'efficientformer_l7', 'efficientnet_b0', 'efficientnet_b1', 'efficientnet_b1_pruned', 'efficientnet_b2', 'efficientnet_b2_pruned', 'efficientnet_b3', 'efficientnet_b3_pruned', 'efficientnet_b4', 'efficientnet_el', 'efficientnet_el_pruned', 'efficientnet_em', 'efficientnet_es', 'efficientnet_es_pruned', 'efficientnet_lite0', 'efficientnetv2_rw_m', 'efficientnetv2_rw_s', 'efficientnetv2_rw_t', 'ens_adv_inception_resnet_v2', 'ese_vovnet19b_dw', ...

# %%
model = timm.create_model('vit_base_patch16_384', pretrained=True)

# %%
model = timm.create_model('rexnet_200', pretrained=True)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rexnet/rexnetv1_200-8c0b7f2d.pth" to /opt/ml/.cache/torch/hub/checkpoints/rexnetv1_200-8c0b7f2d.pth

# %%
print(model)
# Out:
# ReXNetV1(
#   (stem): ConvNormAct(
#     (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn): BatchNormAct2d(
#       64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): SiLU(inplace=True)
#     )
#   )
#   (features): Sequential(
#     (0): LinearBottleneck(
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (bn): BatchNormAct2d(
#           64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (1): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#         (bn): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(192, 54, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           54, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (2): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(54, 324, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(324, 324, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=324, bias=False)
#         (bn): BatchNormAct2d(
#           324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(324, 77, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           77, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (3): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(77, 462, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           462, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(462, 462, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=462, bias=False)
#         (bn): BatchNormAct2d(
#           462, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(462, 38, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(38, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(38, 462, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(462, 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (4): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(100, 600, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(600, 600, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=600, bias=False)
#         (bn): BatchNormAct2d(
#           600, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(600, 50, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(50, 600, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(600, 122, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           122, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (5): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(122, 732, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           732, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(732, 732, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=732, bias=False)
#         (bn): BatchNormAct2d(
#           732, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(732, 61, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(61, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(61, 732, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(732, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (6): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#         (bn): BatchNormAct2d(
#           864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(864, 72, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(72, 864, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(864, 167, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           167, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (7): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(167, 1002, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1002, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1002, 1002, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1002, bias=False)
#         (bn): BatchNormAct2d(
#           1002, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1002, 83, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(83, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(83, 1002, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1002, 190, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           190, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (8): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(190, 1140, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1140, 1140, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1140, bias=False)
#         (bn): BatchNormAct2d(
#           1140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1140, 95, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(95, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(95, 1140, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1140, 212, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           212, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (9): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(212, 1272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1272, 1272, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1272, bias=False)
#         (bn): BatchNormAct2d(
#           1272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1272, 106, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(106, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(106, 1272, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1272, 234, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (10): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(234, 1404, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1404, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1404, 1404, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1404, bias=False)
#         (bn): BatchNormAct2d(
#           1404, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1404, 117, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(117, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(117, 1404, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1404, 257, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           257, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (11): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(257, 1542, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1542, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1542, 1542, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=1542, bias=False)
#         (bn): BatchNormAct2d(
#           1542, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1542, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 1542, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1542, 280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (12): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(280, 1680, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1680, 1680, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1680, bias=False)
#         (bn): BatchNormAct2d(
#           1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1680, 140, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(140, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(140, 1680, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1680, 302, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           302, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (13): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(302, 1812, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1812, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1812, 1812, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1812, bias=False)
#         (bn): BatchNormAct2d(
#           1812, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1812, 151, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(151, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(151, 1812, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1812, 324, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (14): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(324, 1944, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           1944, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(1944, 1944, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1944, bias=False)
#         (bn): BatchNormAct2d(
#           1944, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(1944, 162, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(162, 1944, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(1944, 347, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           347, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (15): LinearBottleneck(
#       (conv_exp): ConvNormAct(
#         (conv): Conv2d(347, 2082, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           2082, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#       )
#       (conv_dw): ConvNormAct(
#         (conv): Conv2d(2082, 2082, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2082, bias=False)
#         (bn): BatchNormAct2d(
#           2082, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#       (se): SEModule(
#         (fc1): Conv2d(2082, 173, kernel_size=(1, 1), stride=(1, 1))
#         (bn): BatchNorm2d(173, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(173, 2082, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act_dw): ReLU6()
#       (conv_pwl): ConvNormAct(
#         (conv): Conv2d(2082, 370, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNormAct2d(
#           370, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#       )
#     )
#     (16): ConvNormAct(
#       (conv): Conv2d(370, 2560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNormAct2d(
#         2560, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#         (drop): Identity()
#         (act): SiLU(inplace=True)
#       )
#     )
#   )
#   (head): ClassifierHead(
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=2560, out_features=1000, bias=True)
#     (flatten): Identity()
#   )
# )

# %%
# !wget https://raw.githubusercontent.com/Iamsdt/DLProjects/master/utils/Helper.py
# Out:
# --2022-11-02 04:06:15--  https://raw.githubusercontent.com/Iamsdt/DLProjects/master/utils/Helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21413 (21K) [text/plain]
# Saving to: ‘Helper.py’
#
# Helper.py           100%[===================>]  20.91K  --.-KB/s    in 0s
#
# 2022-11-02 04:06:15 (59.1 MB/s) - ‘Helper.py’ saved [21413/21413]

# %%
root_train = '/opt/ml/input/data/train/images'
root_test = '/opt/ml/input/data/eval/images'

# %%
import Helper
import torch
from torchvision import datasets, transforms,models
from torch.utils.data import DataLoader

mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
                                transforms.Resize(255),
                                transforms.RandomResizedCrop(224),
                                transforms.RandomHorizontalFlip(),
                                transforms.ColorJitter(),
                                transforms.ToTensor(),
                                transforms.Normalize(mean, std)])

test_transform = transforms.Compose([
                                transforms.Resize(255),
                                transforms.CenterCrop(224),
                                transforms.ToTensor(),
                                transforms.Normalize(mean, std)])

train_loader, test_loader, classes, class_to_idx = Helper.prepare_loader(
    root_train, root_test, train_transform, test_transform)

print("Total Class: ", len(classes))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/ml/baseline/v2/test_ensembel.ipynb Cell 3 in <cell line: 23>()
#       <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> train_transform = transforms.Compose([
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>                                 transforms.Resize(255),
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>                                 transforms.RandomResizedCrop(224),
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>                                 transforms.ToTensor(),
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>                                 transforms.Normalize(mean, std)])
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> test_transform = transforms.Compose([
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a>                                 transforms.Resize(255),
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>                                 transforms.CenterCrop(224),
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>                                 transforms.ToTensor(),
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>                                 transforms.Normalize(mean, std)])
# ---> <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> train_loader, test_loader, classes, class_to_idx = Helper.prepare_loader(
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     root_train, root_test, train_transform, test_transform)
#      <a href='vscode-notebook-cell://ssh-remote%2Baistage/opt/ml/baseline/v2/test_ensembel.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> print("Total Class: ", len(classes))
#
# File ~/baseline/v2/Helper.py:28, in prepare_loader(root_train, root_test, train_transform, test_transforms, batch_size, num_workers)
#      26 # data set
#      27 train_data = datasets.ImageFolder(root_train, transform=train_transform)
# ---> 28 test_data = datasets.ImageFolder(root_test, transform=test_transforms)
#      30 print("Train size:{}".format(len(train_data)))
#      31 print("Valid size:{}".format(len(test_data)))
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/folder.py:310, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file)
#     302 def __init__(
#     303     self,
#     304     root: str,
#    (...)
#     308     is_valid_file: Optional[Callable[[str], bool]] = None,
#     309 ):
# --> 310     super().__init__(
#     311         root,
#     312         loader,
#     313         IMG_EXTENSIONS if is_valid_file is None else None,
#     314         transform=transform,
#     315         target_transform=target_transform,
#     316         is_valid_file=is_valid_file,
#     317     )
#     318     self.imgs = self.samples
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/folder.py:145, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     135 def __init__(
#     136     self,
#     137     root: str,
#    (...)
#     142     is_valid_file: Optional[Callable[[str], bool]] = None,
#     143 ) -> None:
#     144     super().__init__(root, transform=transform, target_transform=target_transform)
# --> 145     classes, class_to_idx = self.find_classes(self.root)
#     146     samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     148     self.loader = loader
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/folder.py:219, in DatasetFolder.find_classes(self, directory)
#     192 def find_classes(self, directory: str) -> Tuple[List[str], Dict[str, int]]:
#     193     """Find the class folders in a dataset structured as follows::
#     194
#     195         directory/
#    (...)
#     217         (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     218     """
# --> 219     return find_classes(directory)
#
# File /opt/conda/lib/python3.8/site-packages/torchvision/datasets/folder.py:43, in find_classes(directory)
#      41 classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42 if not classes:
# ---> 43     raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#      45 class_to_idx = {cls_name: i for i, cls_name in enumerate(classes)}
#      46 return classes, class_to_idx
#
# FileNotFoundError: Couldn't find any class folder in /opt/ml/input/data/eval/images.
